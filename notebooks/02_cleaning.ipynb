# %% [markdown]
# # 02 - Cleaning\nStandardize raw statements, engineer features, and export cleaned dataset.

# %%
import pandas as pd\n\nfrom src.cleaning.cleaner import run_cleaning

# %%
year = "2025"\ncleaned, report, output_path = run_cleaning(year=year)\noutput_path

# %%
report

# %%
cols = [\n    "period_end",\n    "Revenue",\n    "NetIncome",\n    "OperatingCashFlow",\n    "free_cash_flow",\n    "gross_margin_pct",\n    "runway_months",\n]\nexisting_cols = [c for c in cols if c in cleaned.columns]\ncleaned[existing_cols].tail(12)
